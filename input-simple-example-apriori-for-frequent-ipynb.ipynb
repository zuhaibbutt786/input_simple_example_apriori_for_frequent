# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# # Sample transaction data

# %%
transactions = [
    ['bread', 'milk', 'eggs'],
    ['bread', 'butter', 'jam'],
    ['milk', 'butter', 'eggs'],
    ['bread', 'milk', 'butter', 'jam'],
    ['bread', 'milk', 'eggs', 'butter']
]

# %%
transactions
# Out:
# [['bread', 'milk', 'eggs'],
#  ['bread', 'butter', 'jam'],
#  ['milk', 'butter', 'eggs'],
#  ['bread', 'milk', 'butter', 'jam'],
#  ['bread', 'milk', 'eggs', 'butter']]

# %% [markdown]
# # Transform transactions into a one-hot encoded matrix

# %%
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#    bread  butter   eggs    jam   milk
# 0   True   False   True  False   True
# 1   True    True  False   True  False
# 2  False    True   True  False   True
# 3   True    True  False   True   True
# 4   True    True   True  False   True

# %% [markdown]
# # Use Apriori algorithm to find frequent itemsets

# %%
frequent_itemsets = apriori(df, min_support=0.2, use_colnames=True)
frequent_itemsets
# Out:
#     support                     itemsets
# 0       0.8                      (bread)
# 1       0.8                     (butter)
# 2       0.6                       (eggs)
# 3       0.4                        (jam)
# 4       0.8                       (milk)
# 5       0.6              (butter, bread)
# 6       0.4                (eggs, bread)
# 7       0.4                 (jam, bread)
# 8       0.6                (milk, bread)
# 9       0.4               (eggs, butter)
# 10      0.4                (jam, butter)
# 11      0.6               (butter, milk)
# 12      0.6                 (eggs, milk)
# 13      0.2                  (jam, milk)
# 14      0.2        (eggs, butter, bread)
# 15      0.4         (jam, butter, bread)
# 16      0.4        (milk, butter, bread)
# 17      0.4          (milk, eggs, bread)
# 18      0.2           (milk, jam, bread)
# 19      0.4         (eggs, butter, milk)
# 20      0.2          (jam, butter, milk)
# 21      0.2  (milk, eggs, butter, bread)
# 22      0.2   (milk, jam, butter, bread)

# %% [markdown]
# # Generate association rules

# %%
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)

# %%
rules
# Out:
#               antecedents      consequents  antecedent support  \
# 0                (butter)          (bread)                 0.8
# 1                 (bread)         (butter)                 0.8
# 2                   (jam)          (bread)                 0.4
# 3                  (milk)          (bread)                 0.8
# 4                 (bread)           (milk)                 0.8
# 5                   (jam)         (butter)                 0.4
# 6                (butter)           (milk)                 0.8
# 7                  (milk)         (butter)                 0.8
# 8                  (eggs)           (milk)                 0.6
# 9                  (milk)           (eggs)                 0.8
# 10          (jam, butter)          (bread)                 0.4
# 11           (jam, bread)         (butter)                 0.4
# 12                  (jam)  (butter, bread)                 0.4
# 13          (eggs, bread)           (milk)                 0.4
# 14            (jam, milk)          (bread)                 0.2
# 15         (eggs, butter)           (milk)                 0.4
# 16            (jam, milk)         (butter)                 0.2
# 17  (eggs, butter, bread)           (milk)                 0.2
# 18    (jam, butter, milk)          (bread)                 0.2
# 19     (jam, bread, milk)         (butter)                 0.2
# 20            (jam, milk)  (butter, bread)                 0.2
#
#     consequent support  support  confidence      lift  leverage  conviction  \
# 0                  0.8      0.6        0.75  0.937500     -0.04         0.8
# 1                  0.8      0.6        0.75  0.937500     -0.04         0.8
# 2                  0.8      0.4        1.00  1.250000      0.08         inf
# 3                  0.8      0.6        0.75  0.937500     -0.04         0.8
# 4                  0.8      0.6        0.75  0.937500     -0.04         0.8
# 5                  0.8      0.4        1.00  1.250000      0.08         inf
# 6                  0.8      0.6        0.75  0.937500     -0.04         0.8
# 7                  0.8      0.6        0.75  0.937500     -0.04         0.8
# 8                  0.8      0.6        1.00  1.250000      0.12         inf
# 9                  0.6      0.6        0.75  1.250000      0.12         1.6
# 10                 0.8      0.4        1.00  1.250000      0.08         inf
# 11                 0.8      0.4        1.00  1.250000      0.08         inf
# 12                 0.6      0.4        1.00  1.666667      0.16         inf
# 13                 0.8      0.4        1.00  1.250000      0.08         inf
# 14                 0.8      0.2        1.00  1.250000      0.04         inf
# 15                 0.8      0.4        1.00  1.250000      0.08         inf
# 16                 0.8      0.2        1.00  1.250000      0.04         inf
# 17                 0.8      0.2        1.00  1.250000      0.04         inf
# 18                 0.8      0.2        1.00  1.250000      0.04         inf
# 19                 0.8      0.2        1.00  1.250000      0.04         inf
# 20                 0.6      0.2        1.00  1.666667      0.08         inf
#
#     zhangs_metric
# 0       -0.250000
# 1       -0.250000
# 2        0.333333
# 3       -0.250000
# 4       -0.250000
# 5        0.333333
# 6       -0.250000
# 7       -0.250000
# 8        0.500000
# 9        1.000000
# 10       0.333333
# 11       0.333333
# 12       0.666667
# 13       0.333333
# 14       0.250000
# 15       0.333333
# 16       0.250000
# 17       0.250000
# 18       0.250000
# 19       0.250000
# 20       0.500000

# %% [markdown]
# # Function to find most frequent item brought with the given item

# %%
def find_most_frequent_item(item):
    item = [item]
    item_support = frequent_itemsets[frequent_itemsets['itemsets'] == frozenset(item)]['support'].values[0]
    related_rules = rules[rules['antecedents'] == frozenset(item)]

    if not related_rules.empty:
        most_frequent_item = related_rules.iloc[0]['consequents']
        confidence = related_rules.iloc[0]['confidence'] * 100
        print(f"The most frequent item brought with {item} is {most_frequent_item} with {confidence:.2f}% confidence.")
    else:
        print(f"No frequent association found for {item}.")

# %% [markdown]
# # Get user input for the item

# %% [markdown]
# # Find and print the most frequent item brought with the user-specified item

# %%
user_input = input("Enter the name of the item: ")


find_most_frequent_item(user_input)
# Out:
# Enter the name of the item:  butter
# The most frequent item brought with ['butter'] is frozenset({'bread'}) with 75.00% confidence.
